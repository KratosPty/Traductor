# %%
import pathlib
import random
import string
import re
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import TextVectorization

# %%
# load dataset 
filename = 'deu.txt'

# %%
with open(filename,encoding="utf8") as f:
    lines = f.read().split("\n")[:-1]
text_pairs = []
for line in lines:
    eng, spa = line.split("\t")
    spa = "[start] " + spa + " [end]"
    text_pairs.append((eng, spa))

# %%
for _ in range(931):
    print(random.choice(text_pairs))
# Out:
# ('Kwete.', '[start] comer. [end]')
# ('Ngwena.', '[start] lleve. [end]')
# ('Blitäire.', '[start] Notificar. [end]')
# ('Jata.', '[start] Orilla del mar. [end]')
# ('Doän.', '[start] Ropa. [end]')
# ('Etebareta.', '[start] Primo. [end]')
# ('Niguíra.', '[start] se fue. [end]')
# ('¿Ni ogwó bo ño?', '[start] ¿De qué color son los ojos? [end]')
# ('Nungwe.', '[start] de nosotros. [end]')
# ('Nírien.', '[start] crecer. [end]')
# ('Batibe.', '[start] De repente. [end]')
# ('Bukrä.', '[start] Pulmones. [end]')
# ('Bälen.', '[start] Sabroso. [end]')
# ('Diemie.', '[start] Amparar. [end]')
# ('Jali.', '[start] Risacua. [end]')
# ('Demaine.', '[start] Besar. [end]')
# ('Diteta.', '[start] Recuperar la fuerza. [end]')
# ('Ani basare Steven gondi.', '[start] Vamos a visitar a Steven. [end]')
# ('Ji krai.', '[start] Mochila. [end]')
# ('Dirikä.', '[start] Maestra. [end]')
# ('Di.', '[start] Poder. [end]')
# ('Dikaro.', '[start] Varias veces. [end]')
# ('Ni krógoi migatda kitde, agu migatda medende mie?', '[start] Cuando vienen los enfermeros, ¿dónde ponen las inyecciones? [end]')
# ('Ja jiebti.', '[start] Para atras. [end]')
# ('Bä mie.', '[start] Geh weg! [end]')
# ('Ja rüere.', '[start] Enemigo. [end]')
# ('Chakla.', '[start] Pollitos. [end]')
# ('Dekete.', '[start] Extender. [end]')
# ('Bintin.', '[start] Pronto. [end]')
# ('Jükara.', '[start] Pintura. [end]')
# ('Janäre.', '[start] Igual tamaño. [end]')
# ('Dentari.', '[start] Recoger. [end]')
# ('¿Mä tua ño?', '[start] ¿Comoestas? [end]')
# ('Jürä nuen.', '[start] Insinuar. [end]')
# ('Barera.', '[start] Ya cumplido. [end]')
# ('Bolore.', '[start] Redondo. [end]')
# ('Jukwe tigara.', '[start] Llave. [end]')
# ('Iyan.', '[start] Pene. [end]')
# ('¿Amare?', '[start] ¿dónde está? [end]')
# ('Iti.', '[start] Una persona. [end]')
# ('Tigwe.', '[start] mío. [end]')
# ('Ségwe.', '[start] de aquella. [end]')
# ('Dikaro.', '[start] Bastante. [end]')
# ('Junun.', '[start] Nalga. [end]')
# ('Ngübügen ti kwainda.', '[start] Pasado mañana regresaré. [end]')
# ('Blü.', '[start] Sapo Cantador. [end]')
# ('Jón, bron.', '[start] Sí, vamos. [end]')
# ('Jatoaba.', '[start] Vio. [end]')
# ('Bukrä.', '[start] Pulmones. [end]')
# ('Nötarie.', '[start] Febrero. [end]')
# ('Asio.', '[start] estornudo. [end]')
# ('Erara.', '[start] Ciertamente. [end]')
# ('¿Ame?', '[start] ¿Adonde está? [end]')
# ('Du.', '[start] Bote. [end]')
# ('Döre.', '[start] Ebrio [end]')
# ('Ngwóre.', '[start] La cara. [end]')
# ('Ja rüere.', '[start] Adversario. [end]')
# ('Ngöbö reba móben, Steven, Ja toaida.', '[start] Que Dios quede contigo, Steven, Nos vemos. [end]')
# ('Rüen.', '[start] Pluma. [end]')
# ('Blato.', '[start] Plato. [end]')
# ('Alan.', '[start] Cresta de gallo. [end]')
# ('Jene jene.', '[start] Dividido. [end]')
# ('Ngäne.', '[start] ladrar. [end]')
# ('Bukrä.', '[start] Pulmones. [end]')
# ('Büsal.', '[start] Mojarra. [end]')
# ('Kare.', '[start] verde. [end]')
# ('Blite.', '[start] Hablar. [end]')
# ('Negä.', '[start] desaparece. [end]')
# ('Mä.', '[start] usted. [end]')
# ('Bäna.', '[start] Sabor. [end]')
# ('Tigwe.', '[start] mío. [end]')
# ('Dobore.', '[start] Chocolate. [end]')
# ('Kwati.', '[start] uno. [end]')
# ('I mrä.', '[start] Maíz nuevo. [end]')
# ('Blü.', '[start] Sapo Cantador. [end]')
# ('Echa.', '[start] Zorra. [end]')
# ('Jörän.', '[start] Mosquito. [end]')
# ('¿Gere?', '[start] ¿Que? [end]')
# ('Eteba.', '[start] Hermano. [end]')
# ('Büra.', '[start] Venado. [end]')
# ('Bä mie.', '[start] Geh weg! [end]')
# ('Kare.', '[start] verde. [end]')
# ('Ngwean.', '[start] dinero. [end]')
# ('Bererie.', '[start] Julio. [end]')
# ('Itrani.', '[start] Orine. [end]')
# ('Ñurie.', '[start] Junio. [end]')
# ('Ye kwetregwe.', '[start] ese es de ellos. [end]')
# ('Dela.', '[start] Capisucia. [end]')
# ('Griere.', '[start] Con diarrea. [end]')
# ('Ja tötike.', '[start] Estudiar. [end]')
# ('Jürä nuen.', '[start] Insinuar. [end]')
# ('Jötrö.', '[start] Muy rápido. [end]')
# ('Kideiti.', '[start] rácimos. [end]')
# ('Ti Katdubitdi kitde.', '[start] Vengo de Caña Brava. [end]')
# ('Juta.', '[start] Comunidad. [end]')
# ('¡Ake!', '[start] ¡No molestes! [end]')
# ('Bintin.', '[start] Pronto. [end]')
# ('Abta.', '[start] Por eso. [end]')
# ('Dokwä mie.', '[start] Peluquear. [end]')
# ('Ti.', '[start] yo. [end]')
# ('Ngugwe.', '[start] desplumar. [end]')
# ('Akwe ngwóre klón tugwó kwerere aratdo i kló kwerere.', '[start] Porque la cara parece espina de puerco espín y también barba del maíz. [end]')
# ('Krübäte.', '[start] demasiado. [end]')
# ('Kwe.', '[start] él. [end]')
# ('Bañon.', '[start] Pañuelo. [end]')
# ('Büre jäke.', '[start] Respirar. [end]')
# ('Rüen.', '[start] Pluma. [end]')
# ('Ñadre.', '[start] tomar. [end]')
# ('¿Dre tó ni dogwó ketetde?', '[start] ¿Qué sostiene la cabeza? [end]')
# ('Jän.', '[start] Sí. [end]')
# ('Ani krünbotdó.', '[start] Vamos a la balsería. [end]')
# ('Kärere íe.', '[start] pídalo a él. [end]')
# ('Aja.', '[start] Molestar. [end]')
# ('Ari ja di kórere Ngöböe kwe jodron rügai gare nie.', '[start] Vamos a pedir a Dios que nos haga más inteligentes. [end]')
# ('Duka.', '[start] Aguacate. [end]')
# ('Brimone.', '[start] En condición. [end]')
# ('Dokwä sökö.', '[start] Peinarse. [end]')
# ('Deme.', '[start] Intocable. [end]')
# ('Dobore.', '[start] Pardos. [end]')
# ('Bü.', '[start] Guabo. [end]')
# ('Biti.', '[start] Sobre. [end]')
# ('Nére.', '[start] por aquí. [end]')
# ('Jare.', '[start] Parientes. [end]')
# ('Kare.', '[start] verde. [end]')
# ('Genten.', '[start] Morir. [end]')
# ('Ja müre kete.', '[start] Suicidarse. [end]')
# ('Köbö kwin dego, ngobogre.', '[start] Buen día, niños. [end]')
# ('Jökrä.', '[start] Todo. [end]')
# ('Mungwä.', '[start] mosca. [end]')
# ('Diri jue.', '[start] Escuela. [end]')
# ('Junkue.', '[start] Nudo. [end]')
# ('Äkani.', '[start] Por esa causa. [end]')
# ('kwä kwä.', '[start] ocho. [end]')
# ('Ka kugwenoin botdó kugwe kira.', '[start] Para oir sus cantos y sus historias. [end]')
# ('Gibiekä.', '[start] Aflojarse. [end]')
# ('Billo.', '[start] Anciana. [end]')
# ('Blite gwärere.', '[start] Hablar frente a frente. [end]')
# ('Bobota.', '[start] Sapo. [end]')
# ('Drätike.', '[start] Eructar. [end]')
# ('Ségri.', '[start] al otro lado. [end]')
# ('Aja.', '[start] Molestar. [end]')
# ('Deme.', '[start] Puro. [end]')
# ('Dera.', '[start] Rato. [end]')
# ('Janäre.', '[start] Parejo. [end]')
# ('Tigwe.', '[start] mío. [end]')
# ('Jäme.', '[start] Quieto. [end]')
# ('Bisire.', '[start] Modelo de mochila. [end]')
# ('Bren Käme.', '[start] Contagiosa. [end]')
# ('Itrani.', '[start] Orine. [end]')
# ('Rüen.', '[start] Pluma. [end]')
# ('Buke.', '[start] Alimentar. [end]')
# ('Kuni.', '[start] encontró. [end]')
# ('Gwa.', '[start] Pescado. [end]')
# ('Kwete.', '[start] comer. [end]')
# ('Arabe.', '[start] Lo mismo. [end]')
# ('Ngöbö.', '[start] Dios. [end]')
# ('Dokwä mie.', '[start] Cortar el cabello. [end]')
# ('¿Mó janama köböben setde?', '[start] ¿Cuánto días estuviste allá? [end]')
# ('Jitrasi.', '[start] Moracho. [end]')
# ('Jaknu.', '[start] Siempre. [end]')
# ('Büre Täke.', '[start] Soplar. [end]')
# ('Bätete.', '[start] Lavar. [end]')
# ('Nírien.', '[start] desarrollar. [end]')
# ('Ari ja töe kórere Maria, Jesu meye, kwe ni meye di migai sribibotdó.', '[start] Vamos a pedirle a María, la mamá de Jesús, que ayude a nuestras mamás en sus trabajos. [end]')
# ('Doan.', '[start] Cuñado. [end]')
# ('Bisire.', '[start] Modelo de vestido. [end]')
# ('Gwire.', '[start] Hogar. [end]')
# ('Bosi.', '[start] Cuñada. [end]')
# ('Kwati.', '[start] uno. [end]')
# ('Krübäte.', '[start] demasiado. [end]')
# ('Ja mie kri.', '[start] Jactarse. [end]')
# ('Niguigä.', '[start] bolar. [end]')
# ('Gwaire.', '[start] Juntos. [end]')
# ('Batibe.', '[start] De repente. [end]')
# ('Dirikä.', '[start] Profeta. [end]')
# ('Bän.', '[start] Pez anguila. [end]')
# ('Bötä.', '[start] Seguido. [end]')
# ('Drüne.', '[start] Negro. [end]')
# ('Ja rüere.', '[start] Enemigo. [end]')
# ('Ji ngrabare.', '[start] En el camino. [end]')
# ('Ngwóre.', '[start] La cara. [end]')
# ('Kwin ti ngobo, ja ngubua botdó mógwe ñan dö ñai krubotde.', '[start] Bien hijo, cuídate y no tomes mucha chicha. [end]')
# ('Jorakä.', '[start] Penca. [end]')
# ('Braire.', '[start] Amenazar. [end]')
# ('Bta.', '[start] Por eso. [end]')
# ('Ni króchi, ¿dre tó ni toen ni botdó?', '[start] A los flacos, ¿qué se les nota? [end]')
# ('Ñantöre dego, dirigó.', '[start] Buenos días, maestra. [end]')
# ('Ni dogwóbotdó.', '[start] La cabeza. [end]')
# ('Griere.', '[start] Con diarrea. [end]')
# ('Dera.', '[start] Rato. [end]')
# ('Ibia nie.', '[start] Refresco de caña. [end]')
# ('Juta Ngöbökwe.', '[start] Pueblo de Dios. [end]')
# ('Krä.', '[start] flaco. [end]')
# ('Bä mie.', '[start] Geh weg! [end]')
# ('Kämen.', '[start] malos. [end]')
# ('Blato.', '[start] Plato. [end]')
# ('Blita.', '[start] Conversación. [end]')
# ('kwä kügü.', '[start] siete [end]')
# ('Ja nuente.', '[start] Practicar. [end]')
# ('Bärisi.', '[start] Parecido. [end]')
# ('Bererie.', '[start] Julio. [end]')
# ('Nidan.', '[start] macho. [end]')
# ('Köbö kwin dego, dirigó.', '[start] Buen día, maestra. [end]')
# ('Blo.', '[start] Incorrecto. [end]')
# ('¡Ari!', '[start] ¡Vamos! [end]')
# ('¿Ni ogwó bo ño?', '[start] ¿De qué color son los ojos? [end]')
# ('Bötä.', '[start] Cerca. [end]')
# ('Dobo.', '[start] Tierra. [end]')
# ('Gräkite.', '[start] Actuar. [end]')
# ('Kwäjätä.', '[start] diez. [end]')
# ('Kwäräi.', '[start] Esposa. [end]')
# ('Ka kugwenoin botdó kugwe kira.', '[start] Para oir sus cantos y sus historias. [end]')
# ('Dö.', '[start] Ron. [end]')
# ('Mura.', '[start] gripe. [end]')
# ('Dürü butiere.', '[start] Calvo. [end]')
# ('Joborie.', '[start] Agosto. [end]')
# ('Duin.', '[start] Creer. [end]')
# ('Echa.', '[start] Zorra. [end]')
# ('Kwin Ngöbögróge, ja toaida madangware.', '[start] Gracias a Dios, nos vemos más adelante. [end]')
# ('Bun.', '[start] Varicela. [end]')
# ('Sübrüre.', '[start] amarillo. [end]')
# ('Drankwa kiare.', '[start] Sarampión. [end]')
# ('Ngaña.', '[start] hormiga. [end]')
# ('Gwaire.', '[start] Juntos. [end]')
# ('Bä mie.', '[start] Geh weg! [end]')
# ('Blü.', '[start] Flor. [end]')
# ('Gibiekä.', '[start] Aflojarse. [end]')
# ('Duin.', '[start] Presentir. [end]')
# ('Brare.', '[start] Varón. [end]')
# ('Bärisi.', '[start] Parecido. [end]')
# ('Duin.', '[start] Creer. [end]')
# ('Juta Ngöbökwe.', '[start] Pueblo de Dios. [end]')
# ('Chenka.', '[start] Conchita. [end]')
# ('Na mó, mó ñaka blitdani, ¿mó kó ño?', '[start] Y tú, no has hablado, ¿cómo te llamas? [end]')
# ('Kwe.', '[start] él. [end]')
# ('Biti.', '[start] Sobre. [end]')
# ('Bosi.', '[start] Nuera. [end]')
# ('Komä.', '[start] tres. [end]')
# ('Ti kó Steven Cisneros.', '[start] Me llamo Steven Cisneros. [end]')
# ('Brukwä.', '[start] Corazón. [end]')
# ('Ngin.', '[start] gusano. [end]')
# ('Kare.', '[start] verde. [end]')
# ('Janäre.', '[start] Igual tamaño. [end]')
# ('I mrä.', '[start] Maíz nuevo. [end]')
# ('¿Dre ja dogwó sögö?', '[start] ¿Qué peinamos? [end]')
# ('Bökän.', '[start] Verdad. [end]')
# ('Dobo.', '[start] Tierra. [end]')
# ('Gwero.', '[start] Huevo podrido. [end]')
# ('Dirikä.', '[start] Maestro. [end]')
# ('Jrekäbe.', '[start] Solamente. [end]')
# ('Etbakrä.', '[start] Primo hermano. [end]')
# ('Bämän.', '[start] Domingo. [end]')
# ('Jändrän.', '[start] Cosas. [end]')
# ('Bta.', '[start] Por eso. [end]')
# ('Tata.', '[start] Papá. [end]')
# ('Jlata.', '[start] Cañizo. [end]')
# ('Ti köböni bononde.', '[start] Soñé sabroso. [end]')
# ('Buke.', '[start] Soplar. [end]')
# ('I dru.', '[start] Brusca de maíz. [end]')
# ('Aku.', '[start] Aguja. [end]')
# ('Rubúne.', '[start] enojado. [end]')
# ('Aiteje.', '[start] Susto. [end]')
# ('Juda.', '[start] Nido. [end]')
# ('Blitagwä.', '[start] Emisora. [end]')
# ('Bätä.', '[start] Desprecio. [end]')
# ('Ja muko.', '[start] Compañero. [end]')
# ('Duin.', '[start] Sentir [end]')
# ('Ja töbikaire.', '[start] Preocupado. [end]')
# ('Bökän.', '[start] Simpatía. [end]')
# ('Ja driere.', '[start] Quejarse. [end]')
# ('Blo.', '[start] Malo. [end]')
# ('Bali.', '[start] Bolsillo. [end]')
# ('Gente.', '[start] Ocultar. [end]')
# ('Bänänte.', '[start] Sabroso. [end]')
# ('Gwa.', '[start] Pez. [end]')
# ('Ti Katdubitdi kitde.', '[start] Vengo de Caña Brava. [end]')
# ('¿Giere góre?', '[start] ¿Para qué? [end]')
# ('Kíra.', '[start] antiguo. [end]')
# ('Ti tö rabai netde, kri nura tigwe nögaba bomo kónenbotdó ngubuarebitdi.', '[start] Estoy pensando quedarme aquí para cuidar las semillas de árboles que sembré la semana pasada. [end]')
# ('Büle.', '[start] Barriga. [end]')
# ('Kwärigué.', '[start] cinco. [end]')
# ('Jakare.', '[start] Vergüenza. [end]')
# ('Kegue.', '[start] vaciar. [end]')
# ('Doen.', '[start] Chupar. [end]')
# ('Ogwä.', '[start] ojo. [end]')
# ('Grie.', '[start] Diarrea. [end]')
# ('Kíra.', '[start] viene. [end]')
# ('Kwäräi.', '[start] Esposa. [end]')
# ('Dobore.', '[start] Pardos. [end]')
# ('Migatda ja mregarabotdó.', '[start] En la cintura. [end]')
# ('Jadenkä.', '[start] Jugar. [end]')
# ('Krí.', '[start] grande. [end]')
# ('Üna.', '[start] madurar. [end]')
# ('Blübe.', '[start] Soplado. [end]')
# ('Biti.', '[start] Sobre. [end]')
# ('Bian.', '[start] Mujer Extranjera. [end]')
# ('Kwin Ngöbögróge, ja toaida madangware.', '[start] Gracias a Dios, nos vemos más adelante. [end]')
# ('Jadenkä.', '[start] Jugar. [end]')
# ('Ibia mnun.', '[start] Azúcar. [end]')
# ('Drüne.', '[start] Negros. [end]')
# ('Jukwe tigara.', '[start] Llave. [end]')
# ('Chakla.', '[start] Pollitos. [end]')
# ('Mäe.', '[start] a usted. [end]')
# ('Gwi.', '[start] Dentro de casa. [end]')
# ('Deo.', '[start] Noche. [end]')
# ('komä.', '[start] tres. [end]')
# ('Tidróbitdi.', '[start] Con la lengua. [end]')
# ('Ju.', '[start] Edificio. [end]')
# ('Jäe.', '[start] Malestar. [end]')
# ('Rüen.', '[start] Vello. [end]')
# ('Bren.', '[start] Enfermo. [end]')
# ('Bötä.', '[start] En. [end]')
# ('Diemie.', '[start] Amparar. [end]')
# ('köbö.', '[start] Día. [end]')
# ('Kwati.', '[start] uno. [end]')
# ('Di.', '[start] Fuerza. [end]')
# ('Bötä ngwen.', '[start] Despreciar. [end]')
# ('Drüne.', '[start] Moreno. [end]')
# ('Droa.', '[start] Lonche. [end]')
# ('Jukwe.', '[start] Puerta. [end]')
# ('Aja.', '[start] Molestar. [end]')
# ('Ja mórógó.', '[start] La familia. [end]')
# ('Umbre.', '[start] mayor. [end]')
# ('Jatoaba.', '[start] Vio. [end]')
# ('Jorakä.', '[start] Penca. [end]')
# ('Ti kó Steven.', '[start] Me llamo Steven. [end]')
# ('¿Ngóbe tö tó neme ni klótdea?', '[start] ¿A los Guaymí les gustan los barbudos? [end]')
# ('Kaibe.', '[start] solo. [end]')
# ('Tigwe.', '[start] mío. [end]')
# ('Ibia ngätä.', '[start] Raspadura. [end]')
# ('Gwa.', '[start] Pez. [end]')
# ('Bämänte.', '[start] Velorio. [end]')
# ('Nukro.', '[start] Perro. [end]')
# ('Ngwai.', '[start] hermana. [end]')
# ('Basare.', '[start] Pasear [end]')
# ('köbö.', '[start] Día. [end]')
# ('Gaba.', '[start] Sabía. [end]')
# ('Ja tötikaka.', '[start] Estudiante. [end]')
# ('Bren Käme.', '[start] Contagiosa. [end]')
# ('Ja mie kri.', '[start] Jactarse. [end]')
# ('Acho.', '[start] grosería! [end]')
# ('Käte.', '[start] gordo. [end]')
# ('Blitagwä.', '[start] Emisora. [end]')
# ('Kwä kügü.', '[start] siete. [end]')
# ('Kwe.', '[start] él. [end]')
# ('Brukwä.', '[start] Corazón. [end]')
# ('Jorakä.', '[start] Penca. [end]')
# ('Ngwin.', '[start] Traer. [end]')
# ('Ñóge jodron ñógorótde an ñóge köbotdó.', '[start] Pesar y medir. [end]')
# ('Nende.', '[start] derramar. [end]')
# ('Ban.', '[start] Pan. [end]')
# ('Mó ningögö, Steven, Ngöbö riga móben, ja toaida ngübügen.', '[start] Mentiroso, Steven, Que Dios vaya contigo, nos vemos pasado mañana. [end]')
# ('Eteba.', '[start] Hermano. [end]')
# ('Dokwä druen.', '[start] Cabello. [end]')
# ('Na mó, ¿medende gitde, Steven?', '[start] Y tú, ¿de dónde vienes, Steven? [end]')
# ('Nírien.', '[start] desarrollar. [end]')
# ('Kíra.', '[start] antiguo. [end]')
# ('Alan.', '[start] Cresta de gallo. [end]')
# ('Biti.', '[start] Con. [end]')
# ('Mirie.', '[start] Mayo. [end]')
# ('¡E!', '[start] ¡Ahh! [end]')
# ('Aiteje.', '[start] Susto. [end]')
# ('Séte.', '[start] allá. [end]')
# ('Brare.', '[start] Varón. [end]')
# ('Kó.', '[start] El tiempo. [end]')
# ('Diteta.', '[start] Recuperar la fuerza. [end]')
# ('Ngwana roäre.', '[start] en medio día. [end]')
# ('Blita.', '[start] Conversación. [end]')
# ('Ja ngibiare.', '[start] Esperar. [end]')
# ('Ngwai.', '[start] hermana. [end]')
# ('Ja nuente.', '[start] Enseñar. [end]')
# ('Ngwen.', '[start] blanco. [end]')
# ('Nun.', '[start] nosotros. [end]')
# ('Bämiara toae.', '[start] Televisión. [end]')
# ('Jükara.', '[start] Pintura. [end]')
# ('Käte.', '[start] gordo. [end]')
# ('Blato.', '[start] Plato. [end]')
# ('Ni tó mröre, ¿mrö tó nigen ño?', '[start] Cuando comemos, ¿a dónde va la comida? [end]')
# ('Aiteje.', '[start] Susto. [end]')
# ('Tomäirie.', '[start] Octubre. [end]')
# ('¿Dre tó ni ogwó bitdi kwin?', '[start] ¿Qué tenemos arriba de los ojos? [end]')
# ('Köbo kuin dekä.', '[start] Buenos días. [end]')
# ('Kwe.', '[start] él. [end]')
# ('Dirikä.', '[start] Maestro. [end]')
# ('Bisire.', '[start] Modelo de mochila. [end]')
# ('Buko.', '[start] Chuzo. [end]')
# ('Diri jue.', '[start] Escuela. [end]')
# ('Diore.', '[start] Opaco. [end]')
# ('Kwin Ngöbögróge dego, Maria.', '[start] Hola, María. [end]')
# ('Nun.', '[start] nosotros. [end]')
# ('Bi.', '[start] Suegra. [end]')
# ('Nun kiri.', '[start] a lado de nosotros. [end]')
# ('Dokwä mie.', '[start] Peluquear. [end]')
# ('Jene jene.', '[start] Parte separada. [end]')
# ('Metre.', '[start] cierto. [end]')
# ('Ti dórebare Kwradubitdi.', '[start] Nací en Cerro Gato. [end]')
# ('Büsal.', '[start] Planta. [end]')
# ('Jikwili.', '[start] Pajaro. [end]')
# ('Dirare.', '[start] Claro y limpio. [end]')
# ('Ja rüere.', '[start] Rival. [end]')
# ('Matdare nun bige jatötdigai ni dogwóbotdó, Batdi, niere tie, ¿Sobro migatda medende jae?', '[start] Hoy vamos a estudiar la cabeza Primero, díganme, ¿Dónde se pone el sombrero? [end]')
# ('Dela.', '[start] Capisucia. [end]')
# ('Köbo kuin dere.', '[start] Buenas tardes. [end]')
# ('Ja dätere.', '[start] Vestirse. [end]')
# ('¿Dre bitdi ni tó nigren?', '[start] ¿Con qué vemos? [end]')
# ('Di.', '[start] Fuerza. [end]')
# ('Bötä.', '[start] Pegado. [end]')
# ('Jutra.', '[start] Luz. [end]')
# ('Dite.', '[start] Poderoso. [end]')
# ('Dube.', '[start] Selva. [end]')
# ('Dokwä sökö.', '[start] Peinarse. [end]')
# ('Dokwä druen.', '[start] Cabello. [end]')
# ('Kwä ögän.', '[start] nueve. [end]')
# ('Ju.', '[start] Edificio. [end]')
# ('Judakwata.', '[start] bolsa amniótica. [end]')
# ('Bisire.', '[start] Modelo de vestido. [end]')
# ('Asio.', '[start] estornudo. [end]')
# ('Bökän.', '[start] Simpatía. [end]')
# ('Bökänä.', '[start] Verdaderamente. [end]')
# ('Dera.', '[start] Rato. [end]')
# ('Kuni.', '[start] encontró. [end]')
# ('Bato.', '[start] Pato. [end]')
# ('Ngübügen ti kwainda.', '[start] Pasado mañana regresaré. [end]')
# ('Diemie.', '[start] Amparar. [end]')
# ('Ikle.', '[start] Inglés. [end]')
# ('Gure.', '[start] Casados. [end]')
# ('¿Dre bitdi ni tó jodron róse?', '[start] ¿Con qué olemos? [end]')
# ('Ulíe.', '[start]  pierna. [end]')
# ('Ni tó ngitdiegó, ¿dre tó kitde ne nie?', '[start] Si nos cortamos, ¿qué nos sale? [end]')
# ('Kada.', '[start] boca. [end]')
# ('Ti.', '[start] yo. [end]')
# ('Brae.', '[start] Cazador. [end]')
# ('Ngöbö täräi.', '[start] Biblia. [end]')
# ('¿Ame?', '[start] ¿Adonde está? [end]')
# ('Jürä nuen.', '[start] Insinuar. [end]')
# ('Demaine.', '[start] Besar. [end]')
# ('Dibo mie.', '[start] Enterrar. [end]')
# ('Köbo kuin deu.', '[start] Buenas Noches. [end]')
# ('Ja rüere.', '[start] Rival. [end]')
# ('Roro.', '[start] cuello. [end]')
# ('Bärisi.', '[start] Parecido. [end]')
# ('Brare.', '[start] Varón. [end]')
# ('Dikaro.', '[start] Bastante. [end]')
# ('Joborie.', '[start] Agosto. [end]')
# ('Itire Itire.', '[start] Cada uno. [end]')
# ('Ti tä tärä driere.', '[start] yo estoy enseñando. [end]')
# ('Chiki.', '[start] Perrito. [end]')
# ('Mä niguí medénde.', '[start] ¿Usted adónde va? [end]')
# ('Janama.', '[start] Fue. [end]')
# ('Kíra.', '[start] antiguo. [end]')
# ('Bule.', '[start] Barriga [end]')
# ('Äkani.', '[start] Por esa causa. [end]')
# ('Malan.', '[start] mariposa. [end]')
# ('Bukroän.', '[start] Pulmón [end]')
# ('Jikwili.', '[start] Pajaro. [end]')
# ('Ngaña.', '[start] hormiga. [end]')
# ('Ötöiti.', '[start] un vestido. [end]')
# ('Ju.', '[start] Bazo. [end]')
# ('Ye tigwe.', '[start] eso es mío. [end]')
# ('Ani basare Steven gondi.', '[start] Vamos a visitar a Steven. [end]')
# ('Betekä.', '[start] Explotar. [end]')
# ('Blato.', '[start] Plato. [end]')
# ('Dobro.', '[start] Charco. [end]')
# ('Ti tä tärä driere.', '[start] yo estoy enseñando. [end]')
# ('Bätä.', '[start] Desprecio. [end]')
# ('Junun.', '[start] Nalga. [end]')
# ('¿Ñaka tó nemendea?', '[start] ¿Y no queda nada? [end]')
# ('Dokwä täke.', '[start] Impedir.. [end]')
# ('Drüne.', '[start] Moreno. [end]')
# ('Né ñain.', '[start] tome este. [end]')
# ('Kwegwe.', '[start] de él. [end]')
# ('Gokä.', '[start] Ladrón. [end]')
# ('Jadenkä.', '[start] Deporte. [end]')
# ('Gwi.', '[start] En casa. [end]')
# ('Bren Käme.', '[start] Contagiosa. [end]')
# ('Krisiminsi.', '[start] Diciembre. [end]')
# ('Abta.', '[start] Por eso. [end]')
# ('Kíra.', '[start] antiguo. [end]')
# ('Meke.', '[start] Madre. [end]')
# ('Gobran.', '[start] Corregidor. [end]')
# ('Mungwä.', '[start] mosca. [end]')
# ('Nugwä.', '[start] pájaro. [end]')
# ('Jataba.', '[start] Vino. [end]')
# ('Bren.', '[start] Enfermedades. [end]')
# ('Jikwili.', '[start] Pajaro. [end]')
# ('Krene.', '[start] perezoso. [end]')
# ('Bukere.', '[start] Celeste. [end]')
# ('I döi.', '[start] Chicha de maíz. [end]')
# ('Buke.', '[start] Soplar. [end]')
# ('Deu.', '[start] Noche. [end]')
# ('Ja muko.', '[start] Compañero. [end]')
# ('Jäkäni.', '[start] Haló. [end]')
# ('Gente.', '[start] Ocultar. [end]')
# ('Angwane.', '[start] Cuando. [end]')
# ('Kwärigué.', '[start] cinco. [end]')
# ('Bokro.', '[start] Fósforo. [end]')
# ('Jetebe.', '[start] Mañana. [end]')
# ('Jetebe.', '[start] Mañana. [end]')
# ('Duka.', '[start] Aguacate. [end]')
# ('Drüne.', '[start] Moreno. [end]')
# ('Akwe ngwóre klón tugwó kwerere aratdo i kló kwerere.', '[start] Porque la cara parece espina de puerco espín y también barba del maíz. [end]')
# ('Icha.', '[start] Culebra. [end]')
# ('Jädriane.', '[start] Ayer. [end]')
# ('Janäre.', '[start] Parejo. [end]')
# ('Ji ngwen.', '[start] Guiar. [end]')
# ('Tata.', '[start] Padre. [end]')
# ('Jüben.', '[start] Bañarse. [end]')
# ('Kwäräi.', '[start] Esposo. [end]')
# ('Erebe.', '[start] Igual. [end]')
# ('Bätete.', '[start] Lavar. [end]')
# ('Ni ogwó druen.', '[start] Las cejas. [end]')
# ('Buke.', '[start] Alimentar. [end]')
# ('Gente.', '[start] Ocultar. [end]')
# ('Be.', '[start] Zapallo. [end]')
# ('Chichikwata.', '[start] Ruiseñor. [end]')
# ('Ibia mnun.', '[start] Azúcar. [end]')
# ('Dikente.', '[start] Destruir. [end]')
# ('Bätäre.', '[start] Despacio. [end]')
# ('Jatoaba.', '[start] Vio. [end]')
# ('Chi.', '[start] Pequeño. [end]')
# ('Batata.', '[start] Alrededor. [end]')
# ('Metre.', '[start] cierto. [end]')
# ('Ogwógwatda.', '[start] Párpados. [end]')
# ('Doen.', '[start] Chupar. [end]')
# ('Gwaire.', '[start] Juntos. [end]')
# ('Jón, bron.', '[start] Sí, vamos. [end]')
# ('Bäsekä.', '[start] Barrer. [end]')
# ('Jakwite.', '[start] Disfrazar. [end]')
# ('Dibire.', '[start] Nocturno. [end]')
# ('Mungwä.', '[start] mosca. [end]')
# ('komä.', '[start] tres. [end]')
# ('Üna.', '[start] completo. [end]')
# ('Dobrore.', '[start] Sucia. [end]')
# ('Bi.', '[start] Suegra. [end]')
# ('Chokali.', '[start] Espiritu maligno. [end]')
# ('Nére.', '[start] por aquí. [end]')
# ('Droasi.', '[start] Mono cara blanca. [end]')
# ('Bänänte.', '[start] Sabroso. [end]')
# ('Gokä.', '[start] Ladrón. [end]')
# ('Bätete.', '[start] Lavar. [end]')
# ('Ja nuente.', '[start] Enseñar. [end]')
# ('Ja dogwóbitdi.', '[start] Sobre la cabeza. [end]')
# ('An.', '[start] Y. [end]')
# ('Kwärä.', '[start] al lado. [end]')
# ('Nére.', '[start] por aquí. [end]')
# ('Jukwe.', '[start] Puerta. [end]')
# ('Nukro.', '[start] Perro. [end]')
# ('Bäsi.', '[start] Casi. [end]')
# ('Judakwata.', '[start] bolsa amniótica. [end]')
# ('Gü.', '[start] Lechuza. [end]')
# ('Ketéiti.', '[start] un paquete. [end]')
# ('Törie.', '[start] Enero. [end]')
# ('Köböiti.', '[start] un día. [end]')
# ('Dokwä mie.', '[start] Peluquear. [end]')
# ('Brän.', '[start] Vamos. [end]')
# ('Kada.', '[start] boca. [end]')
# ('Muríe.', '[start] aire. [end]')
# ('Kite.', '[start] tire. [end]')
# ('Abko.', '[start] Eso es! [end]')
# ('Be nice.', '[start] Señalar. [end]')
# ('Mura.', '[start] gripe. [end]')
# ('Ji ngwen.', '[start] Guiar. [end]')
# ('Ogwógwatda.', '[start] Párpados. [end]')
# ('kwati.', '[start] uno. [end]')
# ('Nigwe jatödigaba ni ogwóbotdó jodrin Matdare, ni bige jatödige ni ngrabare.', '[start] Ayer estudiamos la cabeza, Hoy vamos a estudiar el cuerpo humano. [end]')
# ('Bule.', '[start] Barriga [end]')
# ('Dentari.', '[start] Salvar. [end]')
# ('Brükwä.', '[start] Corazón. [end]')
# ('Bökänä.', '[start] Verdaderamente. [end]')
# ('Aja.', '[start] Molestar. [end]')
# ('Aiteje.', '[start] Susto. [end]')
# ('Ogwä.', '[start] ojo. [end]')
# ('Dobo.', '[start] Tierra. [end]')
# ('Bämiara toae.', '[start] Televisión. [end]')
# ('¿Ni ogwó bo ño?', '[start] ¿De qué color son los ojos? [end]')
# ('Motdróró.', '[start] El pecho. [end]')
# ('Ngöbö.', '[start] Dios. [end]')
# ('Kwäräi.', '[start] Esposo. [end]')
# ('Büsal.', '[start] Mojarra. [end]')
# ('Jube.', '[start] Ropa grande. [end]')
# ('Gobran.', '[start] Gorbenador. [end]')
# ('Ni junungróbitdi.', '[start] En las nalgas. [end]')
# ('Jötrö Jötrö.', '[start] Constantemente. [end]')
# ('¿Dre ja dogwó sögö?', '[start] ¿Qué peinamos? [end]')
# ('Gobran.', '[start] Presidente. [end]')
# ('¿Ni ngwóregri ye kó ño?', '[start] ¿Cómo se llama la parte de adelante del cuerpo? [end]')
# ('Drätike.', '[start] Eructar. [end]')
# ('Ji ngwen.', '[start] Guiar. [end]')
# ('Diore.', '[start] Lejano. [end]')
# ('Gätäre.', '[start] Reunirse. [end]')
# ('Bämän tike.', '[start] Hace velorio. [end]')
# ('Kürera.', '[start] terminaron. [end]')
# ('Gibiekä.', '[start] Divorcearse. [end]')
# ('¿Dre tó ni dogwó ketetde?', '[start] ¿Qué sostiene la cabeza? [end]')
# ('Abu.', '[start] desobedencia. [end]')
# ('Gwi.', '[start] Dentro de casa. [end]')
# ('Bänä noen.', '[start] Saborear. [end]')
# ('Ibia.', '[start] Caña. [end]')
# ('Junkue.', '[start] Nudo. [end]')
# ('Blitakrä.', '[start] Teléfono. [end]')
# ('Kíra.', '[start] antiguo. [end]')
# ('Diore.', '[start] Opaco. [end]')
# ('Ti kó Steven.', '[start] Me llamo Steven. [end]')
# ('Nugwä.', '[start] pájaro. [end]')
# ('Ñgänga.', '[start] Hija. [end]')
# ('Drüne.', '[start] Negro. [end]')
# ('Dirikä.', '[start] Pastora. [end]')
# ('Deu.', '[start] Noche. [end]')
# ('Dekete.', '[start] Extender. [end]')
# ('Köbö kwin dego, dirigó.', '[start] Buen día, maestra. [end]')
# ('Krí.', '[start] grande. [end]')
# ('¿Ñaka tó nemendea?', '[start] ¿Y no queda nada? [end]')
# ('Ani sribi gondi.', '[start] Vamos al campo. [end]')
# ('Ngire.', '[start] caliente. [end]')
# ('¿Mó tó nüne medende?', '[start] ¿Dónde vives? [end]')
# ('Ogwä.', '[start] ojo. [end]')
# ('Dünkwä.', '[start] Puntiagudo. [end]')
# ('Jatobti.', '[start] Voluntad. [end]')
# ('Nigwe jatödigaba ni ogwóbotdó jodrin Matdare, ni bige jatödige ni ngrabare.', '[start] Ayer estudiamos la cabeza, Hoy vamos a estudiar el cuerpo humano. [end]')
# ('Chen.', '[start] Persona morena. [end]')
# ('Jokorie.', '[start] Noviembre. [end]')
# ('Ngwena.', '[start] lleve. [end]')
# ('Ja rüere.', '[start] Rival. [end]')
# ('Yéte.', '[start] ahí. [end]')
# ('Ju.', '[start] Bazo. [end]')
# ('¿Dre tó ni ogwó bitdi kwin?', '[start] ¿Qué tenemos arriba de los ojos? [end]')
# ('Bökän.', '[start] Verdad. [end]')
# ('An.', '[start] Y. [end]')
# ('Gwä.', '[start] Ahorita. [end]')
# ('Bobre.', '[start] Humilde. [end]')
# ('Chara.', '[start] Frijol pintado. [end]')
# ('Dräire.', '[start] Distribuir. [end]')
# ('Tidróbitdi.', '[start] Con la lengua. [end]')
# ('Bobo.', '[start] Pájaro. [end]')
# ('Ngwen.', '[start] blanco. [end]')
# ('Bali.', '[start] Bolsillo. [end]')
# ('Drinri.', '[start] Insecto. [end]')
# ('Ngöbö reba móben, Steven, Ja toaida.', '[start] Que Dios quede contigo, Steven, Nos vemos. [end]')
# ('Ben.', '[start] Con ella. [end]')
# ('Ti kó Steven.', '[start] Me llamo Steven. [end]')
# ('Trägwata.', '[start] una bolsa plástica. [end]')
# ('Ja dätere.', '[start] Arreglarse. [end]')
# ('Ti kó Steven.', '[start] Me llamo Steven. [end]')
# ('Blore.', '[start] Actuar mal [end]')
# ('Junun.', '[start] Nalga. [end]')
# ('Kwegwe.', '[start] de él. [end]')
# ('Krä.', '[start] flaco. [end]')
# ('Kürera.', '[start] terminaron. [end]')
# ('Erebe.', '[start] Igual. [end]')
# ('Köbo kuin dere.', '[start] Buenas tardes. [end]')
# ('¿Dre kugwe, Steven?', '[start] ¿Qué tal, Steven? [end]')
# ('Akwre.', '[start] Venga. [end]')
# ('¡Ari!', '[start] ¡Vamos! [end]')
# ('Meke.', '[start] Madre. [end]')
# ('Büre jäke.', '[start] Respirar. [end]')
# ('Ngwen.', '[start] blanco. [end]')
# ('Kare.', '[start] Verdes. [end]')
# ('¡Ake!', '[start] ¡No molestes! [end]')
# ('Ñain.', '[start] tome. [end]')
# ('Ti Katdubitdi kitde.', '[start] Vengo de Caña Brava. [end]')
# ('Duin.', '[start] Lastimar. [end]')
# ('Blitagwä.', '[start] Emisora. [end]')
# ('Blotu.', '[start] Meseta. [end]')
# ('Rüen.', '[start] Pluma. [end]')
# ('brare.', '[start] Hombre. [end]')
# ('Ja töbikaire.', '[start] Preocupado. [end]')
# ('Acho.', '[start] grosería! [end]')
# ('Diemie.', '[start] Amparar. [end]')
# ('Ja nuente.', '[start] Practicar. [end]')
# ('Ñadre.', '[start] tomar. [end]')
# ('Dike.', '[start] Coser. [end]')
# ('¿Medende korea migatda jae?', '[start] ¿Dónde se pone la correa? [end]')
# ('Mungwä.', '[start] mosca. [end]')
# ('Köbö kwin, Steven.', '[start] Buen día, Steven. [end]')
# ('Bämän.', '[start] Domingo. [end]')
# ('Blo.', '[start] Incorrecto. [end]')
# ('Ie.', '[start] A el. [end]')
# ('Ni dórie.', '[start] La sangre. [end]')
# ('Blure.', '[start] Azul. [end]')
# ('Meke.', '[start] Madre. [end]')
# ('Duin.', '[start] Sentir [end]')
# ('Blübe.', '[start] Soplado. [end]')
# ('Grine.', '[start] Afilado. [end]')
# ('Ni ogwóbitdi.', '[start] Con los ojos. [end]')
# ('Gwärere.', '[start] Públicamente. [end]')
# ('Deo.', '[start] Noche. [end]')
# ('Bron jadengo.', '[start] Vamos a jugar. [end]')
# ('Domi.', '[start] Bejuco. [end]')
# ('kwätí.', '[start] seis. [end]')
# ('Genten.', '[start] Adormecer. [end]')
# ('Öba.', '[start] avispa. [end]')
# ('Biti.', '[start] Después. [end]')
# ('Yé.', '[start] ése. [end]')
# ('Gwi.', '[start] En la casa. [end]')
# ('Blita.', '[start] Conversación. [end]')
# ('Gwrie.', '[start] Morado. [end]')
# ('Köte.', '[start] gordo. [end]')
# ('Jäe.', '[start] Malestar. [end]')
# ('Jrekäbe.', '[start] Solamente. [end]')
# ('Köbo kuin deu.', '[start] Buenas Noches. [end]')
# ('Ñü.', '[start] Lluvia. [end]')
# ('Giteckä.', '[start] Empujar. [end]')
# ('Ñötde.', '[start] En la quebrada. [end]')
# ('Blitäire.', '[start] Notificar. [end]')
# ('Bärisi.', '[start] Parecido. [end]')
# ('Ti kó Steven.', '[start] Me llamo Steven. [end]')
# ('¿Ni tó ja mige ye gondi kó ño?', '[start] ¿Cómo se llama donde uno se pinta? [end]')
# ('Ibia.', '[start] Caña. [end]')
# ('Gwero.', '[start] Huevo podrido. [end]')
# ('Bi.', '[start] Suegra. [end]')
# ('¿Mó noin medende jetdebe?', '[start] ¿A dónde irás mañana? [end]')
# ('Mura.', '[start] gripe. [end]')
# ('Brutu.', '[start] Pecho. [end]')
# ('Jän.', '[start] Sí. [end]')
# ('Dirikä.', '[start] Pastor. [end]')
# ('Nírien.', '[start] crecer. [end]')
# ('Bugere.', '[start] Azules. [end]')
# ('Dokwä mie.', '[start] Cortar el cabello. [end]')
# ('Köbö kwin dego, dirigó.', '[start] Buen día, maestra. [end]')
# ('Jüke.', '[start] Silbar. [end]')
# ('Metre.', '[start] cierto. [end]')
# ('Mun.', '[start] ustedes. [end]')
# ('Ti tö rabai netde, kri nura tigwe nögaba bomo kónenbotdó ngubuarebitdi.', '[start] Estoy pensando quedarme aquí para cuidar las semillas de árboles que sembré la semana pasada. [end]')
# ('Krati.', '[start] un animal. [end]')
# ('Ñain.', '[start] tome. [end]')
# ('Iti.', '[start] Una persona. [end]')
# ('Jura, betdego.', '[start] Apúrate, corre. [end]')
# ('Bali.', '[start] Bolsillo. [end]')
# ('Chara.', '[start] Frijol pintado. [end]')
# ('Ngwäre.', '[start] cara. [end]')
# ('Ti jani basare botdó blitde roaben.', '[start] Fui a visitar y a hablar con un abuelo. [end]')
# ('Jä.', '[start] Roca. [end]')
# ('Jón, bron.', '[start] Sí, vamos. [end]')
# ('Brutu.', '[start] Pecho. [end]')
# ('Ni bren.', '[start] Los enfermos. [end]')
# ('Denkä.', '[start] Sacar. [end]')
# ('Jokoire.', '[start] Septiembre. [end]')
# ('Jäme.', '[start] Manso. [end]')
# ('Ni tó ngitdiegó, ¿dre tó kitde ne nie?', '[start] Si nos cortamos, ¿qué nos sale? [end]')
# ('Kwetre.', '[start] ellos. [end]')
# ('Domi.', '[start] Bejuco. [end]')
# ('Nirégwe.', '[start] de quién. [end]')
# ('Kwärä.', '[start] al lado. [end]')
# ('Bä.', '[start] Apariencia. [end]')
# ('Dobro.', '[start] Charco. [end]')
# ('Gwäre.', '[start] Rostro. [end]')
# ('Duka.', '[start] Aguacate. [end]')
# ('Käne.', '[start] primero. [end]')
# ('Dela.', '[start] Capisucia. [end]')
# ('Brae.', '[start] Cazador. [end]')
# ('Bäbtä.', '[start] Digno. [end]')
# ('Drankwa.', '[start] Fiebre. [end]')
# ('Betekä.', '[start] Estallar. [end]')
# ('Baran.', '[start] Guineo. [end]')
# ('Bütiere.', '[start] Desnudo. [end]')
# ('Ni ngotdobitdi.', '[start] Con los pies. [end]')
# ('¿Mó janama köböben setde?', '[start] ¿Cuánto días estuviste allá? [end]')
# ('Gokä.', '[start] Ladrón. [end]')
# ('Bta.', '[start] Por eso. [end]')
# ('Ji krai.', '[start] Mochila. [end]')
# ('Dirikä.', '[start] Pastor. [end]')
# ('Gwi.', '[start] Dentro de casa. [end]')
# ('¿Dre bitdi ni tó jodron róse?', '[start] ¿Con qué olemos? [end]')
# ('Jato.', '[start] Potrero. [end]')
# ('Ti janama móderare setde.', '[start] Tres días estuve allí. [end]')
# ('Bü.', '[start] Guabo. [end]')
# ('¿Ñaka tó nemendea?', '[start] ¿Y no queda nada? [end]')
# ('Möre.', '[start] hembra. [end]')
# ('Betekä.', '[start] Estallar. [end]')
# ('Büre kete.', '[start] Detener la respiración. [end]')
# ('Blotu.', '[start] Pico de cerro [end]')
# ('Kwrägri.', '[start]  a otro lado. [end]')
# ('Jodrón.', '[start] Cosillas. [end]')
# ('Baran.', '[start] Guineo. [end]')
# ('Köbö kwin, Steven.', '[start] Buen día, Steven. [end]')
# ('I dru.', '[start] Brusca de maíz. [end]')
# ('Kwe.', '[start] él. [end]')
# ('Jiemike.', '[start] Imitar. [end]')
# ('Blitakrä.', '[start] Telegrafía. [end]')
# ('Blore.', '[start] Actuar mal [end]')
# ('Ti tó nüne Tódobotdó.', '[start] Vivo en Cerro Otoe. [end]')
# ('Nirégwe.', '[start] de quién. [end]')
# ('Ugwen.', '[start] olla. [end]')
# ('Gokä.', '[start] Ladrón. [end]')
# ('Käte.', '[start] gordo. [end]')
# ('Ni króna.', '[start] Las costillas. [end]')
# ('Ani basare.', '[start] Vamos a pasear. [end]')
# ('Ju.', '[start] Bazo. [end]')
# ('Ngin.', '[start] gusano. [end]')
# ('Ieli.', '[start] Especie de pájaro. [end]')
# ('Ni dórie.', '[start] La sangre. [end]')
# ('¿Mó kó ño ngóbere?', '[start] ¿Cómo te llamas en guaymí? [end]')
# ('Bani.', '[start] Aluminio. [end]')
# ('Dirikä.', '[start] Maestro. [end]')
# ('Kíra.', '[start] viejo. [end]')
# ('Basakä.', '[start] Visitante. [end]')
# ('¿Ño?', '[start] ¿Cómo? [end]')
# ('Bökän.', '[start] Verdad. [end]')
# ('Mete.', '[start] péguelo. [end]')
# ('Né.', '[start] éste. [end]')
# ('Niguigä.', '[start] bolar. [end]')
# ('Ulíe.', '[start]  pierna. [end]')
# ('kwärigué.', '[start] cinco. [end]')
# ('Kaibe.', '[start] solo. [end]')
# ('Ni kisebitdi.', '[start] Con las manos. [end]')
# ('Ye tigwe.', '[start] ese es mío. [end]')
# ('Ja dätere.', '[start] Arreglarse. [end]')
# ('Blübe.', '[start] Hinchado. [end]')
# ('¿Ñobotdó?', '[start] ¿Por qué? [end]')
# ('Ti jani basare botdó blitde roaben.', '[start] Fui a visitar y a hablar con un abuelo. [end]')
# ('Ñagare, ni bó kóme.', '[start] No, son feos. [end]')
# ('Jutra.', '[start] Fuego. [end]')
# ('Bisi Bisi.', '[start] Pintado. [end]')
# ('Ngire.', '[start] caliente. [end]')
# ('¿Ni dórie tó noin ño?', '[start] ¿Por dónde camina la sangre? [end]')
# ('Juentari.', '[start] Largar. [end]')
# ('Bani.', '[start] Aluminio. [end]')
# ('Äkani.', '[start] Por esa causa. [end]')
# ('Bosi.', '[start] Nuera. [end]')
# ('Rubúne.', '[start] enojado. [end]')
# ('Ñantöre dego, dirigó.', '[start] Buenos días, maestra. [end]')
# ('Aro.', '[start] Arroz. [end]')
# ('I blu.', '[start] Flor de maíz. [end]')
# ('Akwre.', '[start] Venga. [end]')
# ('Diemie.', '[start] Inclinar [end]')
# ('Arato.', '[start] también [end]')
# ('Ngwena.', '[start] lleve. [end]')
# ('Köte.', '[start] gordo. [end]')
# ('Betekä.', '[start] Correr. [end]')
# ('Jürä nuen.', '[start] Insinuar. [end]')
# ('Gwara.', '[start] Parásito. [end]')
# ('Blo.', '[start] Embarazo. [end]')
# ('Jullali.', '[start] Vagina. [end]')
# ('Acho.', '[start] grosería! [end]')
# ('Jäe.', '[start] Malestar. [end]')
# ('Bererie.', '[start] Julio. [end]')
# ('Jäe.', '[start] Malestar. [end]')
# ('¿Ño?', '[start] ¿Cómo? [end]')
# ('Jene jene.', '[start] Parte separada. [end]')
# ('Mó ningögö, Steven, Ngöbö riga móben, ja toaida ngübügen.', '[start] Mentiroso, Steven, Que Dios vaya contigo, nos vemos pasado mañana. [end]')
# ('Blitäire.', '[start] Comunicar. [end]')
# ('Ni tó mröre, ¿mrö tó nigen ño?', '[start] Cuando comemos, ¿a dónde va la comida? [end]')
# ('Tomäirie.', '[start] Octubre. [end]')
# ('Tukerie.', '[start] Abril. [end]')
# ('Betekä.', '[start] Explotar. [end]')
# ('Dru.', '[start] Mariposa nocturna. [end]')
# ('Ni ngotdobitdi.', '[start] Con los pies. [end]')
# ('Bä mie.', '[start] Geh weg! [end]')
# ('Ni büle.', '[start] La barriga. [end]')
# ('Blato.', '[start] Plato. [end]')
# ('Krübäte.', '[start] demasiado. [end]')
# ('Kíra.', '[start] viene. [end]')
# ('Deme.', '[start] Intocable. [end]')
# ('Krí kä.', '[start] hoja de árbol. [end]')
# ('Buchu.', '[start] Bechita [end]')
# ('Dünkwä.', '[start] Puntiagudo. [end]')
# ('Nun kiri.', '[start] a lado de nosotros. [end]')
# ('¿Gótdó giere botdó?', '[start] ¿Reunión sobre qué? [end]')
# ('¿Ni dórie tó noin ño?', '[start] ¿Por dónde camina la sangre? [end]')
# ('Jädriane.', '[start] Ayer. [end]')
# ('Bintin.', '[start] Nuevo [end]')
# ('Kada.', '[start] boca. [end]')
# ('Kabré.', '[start] montón. [end]')
# ('Asio ngidienkä.', '[start] Estornudar. [end]')
# ('Joborie.', '[start] Agosto. [end]')
# ('Juden.', '[start] Gallote. [end]')
# ('Nére.', '[start] por aquí. [end]')
# ('Gwa.', '[start] Pez. [end]')
# ('Blitagwä.', '[start] Emisora. [end]')
# ('Ötare.', '[start] la mita. [end]')
# ('Jlaka.', '[start] Lagarto. [end]')
# ('Ngübügen ti kwainda.', '[start] Pasado mañana regresaré. [end]')
# ('Jlira jlira.', '[start] Muy flaco. [end]')
# ('Droa.', '[start] Lonche. [end]')
# ('Ti.', '[start] yo. [end]')
# ('Kó.', '[start] El tiempo. [end]')
# ('Ti ta nune.', '[start] yo vivo en. [end]')
# ('Braire.', '[start] Amenazar. [end]')
# ('Ibia ngätä.', '[start] Raspadura. [end]')
# ('Dräire.', '[start] Distribuir. [end]')
# ('Brukwä.', '[start] Corazón. [end]')
# ('Köbö kwin, Steven.', '[start] Buen día, Steven. [end]')
# ('Bosi.', '[start] Cuñada. [end]')
# ('Motdróró.', '[start] El pecho. [end]')
# ('kwärigué.', '[start] cinco. [end]')
# ('Ison.', '[start] Nariz. [end]')
# ('Blitakrä.', '[start] Teléfono. [end]')
# ('Jura, betdego.', '[start] Apúrate, corre. [end]')
# ('Abta.', '[start] Por eso. [end]')
# ('Rubúne.', '[start] enojado. [end]')
# ('Ni króchi, ¿dre tó ni toen ni botdó?', '[start] A los flacos, ¿qué se les nota? [end]')
# ('Jükete.', '[start] Bañarte. [end]')
# ('Néa.', '[start] ésta. [end]')
# ('Kuni.', '[start] encontró. [end]')
# ('Bure.', '[start] Nueva planta. [end]')
# ('Kó krójótdo bitdi krókügü tibitdi.', '[start] Tengo diecisiete años. [end]')
# ('Blo.', '[start] Embarazo. [end]')
# ('Bökän.', '[start] Simpatía. [end]')
# ('¿Dre bitdi ni tó nigren?', '[start] ¿Con qué vemos? [end]')
# ('Ja müre kete.', '[start] Suicidarse. [end]')
# ('Kíra.', '[start] viene. [end]')
# ('Krä.', '[start] flaco. [end]')
# ('Ngaña.', '[start] hormiga. [end]')
# ('¿Ngóbe tö tó neme ni klótdea?', '[start] ¿A los Guaymí les gustan los barbudos? [end]')
# ('Mó ningögö, Steven, Ngöbö riga móben, ja toaida ngübügen.', '[start] Mentiroso, Steven, Que Dios vaya contigo, nos vemos pasado mañana. [end]')
# ('Drüne.', '[start] Negros. [end]')
# ('Jikwili.', '[start] Pajaro. [end]')
# ('Kare.', '[start] verde. [end]')
# ('Brämäne.', '[start] Desmayado. [end]')
# ('Duin.', '[start] Lastimar. [end]')
# ('Dirikä.', '[start] Profesor. [end]')
# ('Dube.', '[start] Selva. [end]')
# ('Kwete.', '[start] comer. [end]')
# ('Jitrasi.', '[start] Moracho. [end]')
# ('Kwärä.', '[start] al lado. [end]')
# ('Dekete.', '[start] Ampliar. [end]')
# ('Blita.', '[start] Diálogo. [end]')
# ('Bien.', '[start] Dar. [end]')
# ('Arabe.', '[start] Lo mismo. [end]')
# ('Bütiere.', '[start] Desnudo. [end]')
# ('Icha.', '[start] Culebra. [end]')
# ('Biti.', '[start] Entonces. [end]')
# ('Akisete.', '[start] Por razon de que. [end]')
# ('Juto.', '[start] Liviano. [end]')
# ('Ti tä tärä driere.', '[start] yo estoy enseñando. [end]')
# ('Bato.', '[start] Pato. [end]')
# ('¡Ari!', '[start] ¡Vamos! [end]')
# ('Mende.', '[start] lejos. [end]')
# ('Ngöbö reba móben, Steven, Ja toaida.', '[start] Que Dios quede contigo, Steven, Nos vemos. [end]')
# ('Mun.', '[start] ustedes. [end]')
# ('Dokwä.', '[start] Tronco. [end]')

# %%
num_val_samples = int(0.15 * len(text_pairs))
num_train_samples = len(text_pairs) - 2 * num_val_samples
train_pairs = text_pairs
val_pairs = text_pairs[num_train_samples : num_train_samples + num_val_samples]
test_pairs = text_pairs[num_train_samples + num_val_samples :]

print(f"{len(text_pairs)} total pairs")
print(f"{len(train_pairs)} training pairs")
print(f"{len(val_pairs)} validation pairs")
print(f"{len(test_pairs)} test pairs")
# Out:
# 930 total pairs
# 930 training pairs
# 139 validation pairs
# 139 test pairs

# %%
strip_chars = string.punctuation + "¿"
strip_chars = strip_chars.replace("[", "")
strip_chars = strip_chars.replace("]", "")

vocab_size = 15000
sequence_length = 20
batch_size = 930


def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(lowercase, "[%s]" % re.escape(strip_chars), "")


eng_vectorization = TextVectorization(
    max_tokens=vocab_size, output_mode="int", output_sequence_length=sequence_length,
)
spa_vectorization = TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=sequence_length + 1,
    standardize=custom_standardization,
)
train_eng_texts = [pair[0] for pair in train_pairs]
train_spa_texts = [pair[1] for pair in train_pairs]
eng_vectorization.adapt(train_eng_texts)
spa_vectorization.adapt(train_spa_texts)

# %%
def format_dataset(eng, spa):
    eng = eng_vectorization(eng)
    spa = spa_vectorization(spa)
    return ({"encoder_inputs": eng, "decoder_inputs": spa[:, :-1],}, spa[:, 1:])


def make_dataset(pairs):
    eng_texts, spa_texts = zip(*pairs)
    eng_texts = list(eng_texts)
    spa_texts = list(spa_texts)
    dataset = tf.data.Dataset.from_tensor_slices((eng_texts, spa_texts))
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(format_dataset)
    return dataset.shuffle(2048).prefetch(16).cache()


train_ds = make_dataset(train_pairs)
val_ds = make_dataset(val_pairs)

# %%
for inputs, targets in train_ds.take(1):
    print(f'inputs["encoder_inputs"].shape: {inputs["encoder_inputs"].shape}')
    print(f'inputs["decoder_inputs"].shape: {inputs["decoder_inputs"].shape}')
    print(f"targets.shape: {targets.shape}")
# Out:
# inputs["encoder_inputs"].shape: (930, 20)
# inputs["decoder_inputs"].shape: (930, 20)
# targets.shape: (930, 20)

# %%
class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super(TransformerEncoder, self).__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.supports_masking = True

    def call(self, inputs, mask=None):
        if mask is not None:
            padding_mask = tf.cast(mask[:, tf.newaxis, tf.newaxis, :], dtype="int32")
        attention_output = self.attention(
            query=inputs, value=inputs, key=inputs, attention_mask=padding_mask
        )
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)


class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, vocab_size, embed_dim, **kwargs):
        super(PositionalEmbedding, self).__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=vocab_size, output_dim=embed_dim
        )
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=embed_dim
        )
        self.sequence_length = sequence_length
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)


class TransformerDecoder(layers.Layer):
    def __init__(self, embed_dim, latent_dim, num_heads, **kwargs):
        super(TransformerDecoder, self).__init__(**kwargs)
        self.embed_dim = embed_dim
        self.latent_dim = latent_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.attention_2 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(latent_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()
        self.supports_masking = True

    def call(self, inputs, encoder_outputs, mask=None):
        causal_mask = self.get_causal_attention_mask(inputs)
        if mask is not None:
            padding_mask = tf.cast(mask[:, tf.newaxis, :], dtype="int32")
            padding_mask = tf.minimum(padding_mask, causal_mask)

        attention_output_1 = self.attention_1(
            query=inputs, value=inputs, key=inputs, attention_mask=causal_mask
        )
        out_1 = self.layernorm_1(inputs + attention_output_1)

        attention_output_2 = self.attention_2(
            query=out_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
        )
        out_2 = self.layernorm_2(out_1 + attention_output_2)

        proj_output = self.dense_proj(out_2)
        return self.layernorm_3(out_2 + proj_output)

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)],
            axis=0,
        )
        return tf.tile(mask, mult)

# %%
embed_dim = 256
latent_dim = 2048
num_heads = 8

encoder_inputs = keras.Input(shape=(None,), dtype="int64", name="encoder_inputs")
x = PositionalEmbedding(sequence_length, vocab_size, embed_dim)(encoder_inputs)
encoder_outputs = TransformerEncoder(embed_dim, latent_dim, num_heads)(x)
encoder = keras.Model(encoder_inputs, encoder_outputs)

decoder_inputs = keras.Input(shape=(None,), dtype="int64", name="decoder_inputs")
encoded_seq_inputs = keras.Input(shape=(None, embed_dim), name="decoder_state_inputs")
x = PositionalEmbedding(sequence_length, vocab_size, embed_dim)(decoder_inputs)
x = TransformerDecoder(embed_dim, latent_dim, num_heads)(x, encoded_seq_inputs)
x = layers.Dropout(0.5)(x)
decoder_outputs = layers.Dense(vocab_size, activation="softmax")(x)
decoder = keras.Model([decoder_inputs, encoded_seq_inputs], decoder_outputs)

decoder_outputs = decoder([decoder_inputs, encoder_outputs])
transformer = keras.Model(
    [encoder_inputs, decoder_inputs], decoder_outputs, name="transformer"
)

# %%
transformer.summary()
# Out:
# Model: "transformer"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  positional_embedding_8 (Positi  (None, None, 256)   3845120     ['encoder_inputs[0][0]']
#  onalEmbedding)
#
#  decoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  transformer_encoder_4 (Transfo  (None, None, 256)   3155456     ['positional_embedding_8[0][0]']
#  rmerEncoder)
#
#  model_9 (Functional)           (None, None, 15000)  12959640    ['decoder_inputs[0][0]',
#                                                                   'transformer_encoder_4[0][0]']
#
# ==================================================================================================
# Total params: 19,960,216
# Trainable params: 19,960,216
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
epochs = 2000  # This should be at least 30 for convergence

transformer.summary()
transformer.compile(
    "rmsprop", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)
transformer.fit(train_ds, epochs=epochs, validation_data=val_ds)
# Out:
# Model: "transformer"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  positional_embedding (Position  (None, None, 256)   3845120     ['encoder_inputs[0][0]']
#  alEmbedding)
#
#  decoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  transformer_encoder (Transform  (None, None, 256)   3155456     ['positional_embedding[0][0]']
#  erEncoder)
#
#  model_1 (Functional)           (None, None, 15000)  12959640    ['decoder_inputs[0][0]',
#                                                                   'transformer_encoder[0][0]']
#
# ==================================================================================================
# Total params: 19,960,216
# Trainable params: 19,960,216
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/2000
# 11/11 [==============================] - 15s 1s/step - loss: 0.0565 - accuracy: 0.8957 - val_loss: 1.5213 - val_accuracy: 0.3805
# Epoch 2/2000
# 11/11 [==============================] - 11s 976ms/step - loss: 0.0321 - accuracy: 0.9258 - val_loss: 1.5469 - val_accuracy: 0.3805
# Epoch 3/2000
# 11/11 [==============================] - 12s 1s/step - loss: 0.0304 - accuracy: 0.9319 - val_loss: 1.4917 - val_accuracy: 0.3805
# Epoch 4/2000
# 11/11 [==============================] - 11s 1s/step - loss: 0.0297 - accuracy: 0.9277 - val_loss: 1.5335 - val_accuracy: 0.3784
# Epoch 5/2000
# 11/11 [==============================] - 12s 1s/step - loss: 0.0312 - accuracy: 0.9239 - val_loss: 1.5087 - val_accuracy: 0.3846
# Epoch 6/2000
# 11/11 [==============================] - 12s 1s/step - loss: 0.0327 - accuracy: 0.9239 - val_loss: 1.4579 - val_accuracy: 0.3867
# Epoch 7/2000
# 11/11 [==============================] - 11s 962ms/step - loss: 0.0338 - accuracy: 0.9192 - val_loss: 1.5404 - val_accuracy: 0.3784
# Epoch 8/2000
# 11/11 [==============================] - 11s 1s/step - loss: 0.0314 - accuracy: 0.9244 - val_loss: 1.6057 - val_accuracy: 0.3805
# Epoch 9/2000
# 11/11 [==============================] - 11s 1s/step - loss: 0.0302 - accuracy: 0.9310 - val_loss: 1.5538 - val_accuracy: 0.3825
# 11/11 [==============================] - 11s 964ms/step - loss: 0.0223 - accuracy: 0.9333 - val_loss: 1.1971 - val_accuracy: 0.5509
# Epoch 1993/2000
# 11/11 [==============================] - 11s 979ms/step - loss: 0.0231 - accuracy: 0.9291 - val_loss: 1.1969 - val_accuracy: 0.5509
# Epoch 1994/2000
# 11/11 [==============================] - 11s 978ms/step - loss: 0.0219 - accuracy: 0.9300 - val_loss: 1.1996 - val_accuracy: 0.5447
# Epoch 1995/2000
# 11/11 [==============================] - 11s 975ms/step - loss: 0.0224 - accuracy: 0.9310 - val_loss: 1.1999 - val_accuracy: 0.5426
# Epoch 1996/2000
# 11/11 [==============================] - 11s 966ms/step - loss: 0.0235 - accuracy: 0.9324 - val_loss: 1.1874 - val_accuracy: 0.5447
# Epoch 1997/2000
# 11/11 [==============================] - 11s 982ms/step - loss: 0.0224 - accuracy: 0.9310 - val_loss: 1.2081 - val_accuracy: 0.5447
# Epoch 1998/2000
# 11/11 [==============================] - 11s 963ms/step - loss: 0.0254 - accuracy: 0.9277 - val_loss: 1.2226 - val_accuracy: 0.5426
# Epoch 1999/2000
# 11/11 [==============================] - 11s 963ms/step - loss: 0.0223 - accuracy: 0.9300 - val_loss: 1.2217 - val_accuracy: 0.5426
# Epoch 2000/2000
# 11/11 [==============================] - 11s 965ms/step - loss: 0.0237 - accuracy: 0.9267 - val_loss: 1.1712 - val_accuracy: 0.3992

# %%
transformer.save_weights('transformer.h5')

# %%
transformer.load_weights('transformer.h5')

# %%
from pickle import load
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences


from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import plot_model
from pickle import load
from numpy import array
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from keras.models import load_model
from keras import models
from numpy import argmax
from nltk.translate.bleu_score import corpus_bleu
from random import shuffle
import joblib  
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf

# %%
spa_vocab = spa_vectorization.get_vocabulary()
spa_index_lookup = dict(zip(range(len(spa_vocab)), spa_vocab))
max_decoded_sentence_length = 20


def decode_sequence(input_sentence):
    tokenized_input_sentence = eng_vectorization([input_sentence])
    decoded_sentence = "[start]"
    for i in range(max_decoded_sentence_length):
        tokenized_target_sentence = spa_vectorization([decoded_sentence])[:, :-1]
        predictions = transformer([tokenized_input_sentence, tokenized_target_sentence])

        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = spa_index_lookup[sampled_token_index]
        decoded_sentence += " " + sampled_token

        if sampled_token == "[end]":
            break
    return decoded_sentence


test_eng_texts = [pair[0] for pair in test_pairs]
for _ in range(30):
    input_sentence = random.choice(test_eng_texts)
    translated = decode_sequence(input_sentence)

# %%
input1 = "¿Mó köböni ño, Steven?"
traduccion = decode_sequence(input1)
print(traduccion)
# Out:
# [start] cómo soñaste steven [end]
